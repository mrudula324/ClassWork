# %% [markdown]
# ### 1. Using the documentation for Recursive Feature Selection, apply this process to the crime dataset to create the best model https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.RFE.html . Since this dataset is so small, you do not need to perform a train-test split. You can select what you’re trying to predict. Be sure to explain what RFE is in the markdown.

# %% [markdown]
# The data (X1, X2, X3, X4, X5, X6, X7) are for each city.
#
# X1 = total overall reported crime rate per 1 million residents
#
# X2 = reported violent crime rate per 100,000 residents
#
# X3 = annual police funding in $/resident
#
# X4 = % of people 25 years+ with 4 yrs. of high school
#
# X5 = % of 16 to 19 year-olds not in highschool and not highschool graduates.
#
# X6 = % of 18 to 24 year-olds in college
#
# X7 = % of people 25 years+ with at least 4 years of college

# %% [markdown]
# #### RFE is a popular feature selection algorithm that predicts features that impact can target variables. RFE has wide variety of approaches that user can choose based on their needs. This model initially uses all the variables/features and appropriate methods are used to eliminate features that has less impact on the target variable. This method is recursively applied on the initial set of variables till the desired number of variables are reached.
#
# #### RFE is a part of sklearn library, and can be used for classificaiton and regression type of problems.

# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

# %%
crime_df=pd.read_csv('crime_data.csv')
crime_df
# Out:
#       X1    X2  X3  X4  X5  X6  X7
# 0    478   184  40  74  11  31  20
# 1    494   213  32  72  11  43  18
# 2    643   347  57  70  18  16  16
# 3    341   565  31  71  11  25  19
# 4    773   327  67  72   9  29  24
# 5    603   260  25  68   8  32  15
# 6    484   325  34  68  12  24  14
# 7    546   102  33  62  13  28  11
# 8    424    38  36  69   7  25  12
# 9    548   226  31  66   9  58  15
# 10   506   137  35  60  13  21   9
# 11   819   369  30  81   4  77  36
# 12   541   109  44  66   9  37  12
# 13   491   809  32  67  11  37  16
# 14   514    29  30  65  12  35  11
# 15   371   245  16  64  10  42  14
# 16   457   118  29  64  12  21  10
# 17   437   148  36  62   7  81  27
# 18   570   387  30  59  15  31  16
# 19   432    98  23  56  15  50  15
# 20   619   608  33  46  22  24   8
# 21   357   218  35  54  14  27  13
# 22   623   254  38  54  20  22  11
# 23   547   697  44  45  26  18   8
# 24   792   827  28  57  12  23  11
# 25   799   693  35  57   9  60  18
# ...

# %%
X=crime_df.drop('X1',axis=1)
y=crime_df['X1']

# %%
reg=LogisticRegression()

# %%
selector = RFE(reg, n_features_to_select=4)

# %%
rfe_sel=selector.fit(X,y)
# Out:
# /Users/shreekar/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/shreekar/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
rfe_sel.support_
# Out:
# array([ True,  True,  True, False,  True, False])

# %%
rfe_sel.ranking_
# Out:
# array([1, 1, 1, 2, 1, 3])

# %% [markdown]
# ### 2. Create a function called digital_root that takes in an integer. Digital root is the recursive sum of all the digits in a number.
# ### Given n, take the sum of the digits of n. If that value has more than one digit, continue reducing in this way until a single-digit number is produced. The input will be a non-negative integer.
# Examples:
# 16 --> 1+6=7
# 942 --> 9+4+2=15 --> 1+5=6
# 132189 --> 1+3+2+1+8+9=24 --> 2+4=6 493193 --> 4+9+3+1+9+3=29 --> 2+9=11

# %%
def digital_root (val):
    sum=0
    for i in (str(val)):
        sum=sum+int(i)
    if len(str(sum))==1:
        return sum
    else:
        sum2=0
        for i in (str(sum)):
            sum2=sum2+int(i)
        return sum2

# %%
digital_root(16)
# Out:
# 7

# %%
digital_root(942)
# Out:
# 6

# %%
digital_root(132189)
# Out:
# 6

# %%
digital_root(493193)
# Out:
# 11
